# %%
# %load_ext autoreload
# %autoreload 2

# %%
import src.scraper

# %%
xeno = src.scraper.Xeno()

# %%
xeno.get_last_page()
# Out:
# 21678

# %%
while True:
    try:
        xeno.start(time_sleep=0)
    except Exception as e:
        print(type(e).__name__)
        print(e)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/volodya/code/python/data_science/Interview/InPhoTech/bird_sound/nb_scraper.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/home/volodya/code/python/data_science/Interview/InPhoTech/bird_sound/nb_scraper.ipynb#ch0000003?line=0'>1</a> while True:
#       <a href='vscode-notebook-cell:/home/volodya/code/python/data_science/Interview/InPhoTech/bird_sound/nb_scraper.ipynb#ch0000003?line=1'>2</a>     try:
# ----> <a href='vscode-notebook-cell:/home/volodya/code/python/data_science/Interview/InPhoTech/bird_sound/nb_scraper.ipynb#ch0000003?line=2'>3</a>         xeno.start(time_sleep=0)
#       <a href='vscode-notebook-cell:/home/volodya/code/python/data_science/Interview/InPhoTech/bird_sound/nb_scraper.ipynb#ch0000003?line=3'>4</a>     except Exception as e:
# ...
