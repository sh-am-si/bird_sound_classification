# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pylab as plt
from pydub import AudioSegment
import gridfs
import bson
from bson.binary import Binary

# %matplotlib inline

# %%
import src.utils

# %%
df = src.utils.generate_df()
df.head()
# Out:
#     key                    name                  sci_name  \
# 0  1259  Golden-billed Saltator  Saltator-aurantiirostris
# 1  1260        Chiguanco Thrush          Turdus-chiguanco
# 2  1261        Chiguanco Thrush          Turdus-chiguanco
# 3  1264  Golden-billed Saltator  Saltator-aurantiirostris
# 4  1265   Rufous-bellied Thrush        Turdus-rufiventris
#
#                     id                                   data-xc-filepath  \
# 0  xc_audio_697285_194  //xeno-canto.org/sounds/uploaded/VLDFGFKOWN/XC...
# 1  xc_audio_697254_195  //xeno-canto.org/sounds/uploaded/VLDFGFKOWN/XC...
# 2  xc_audio_697249_196  //xeno-canto.org/sounds/uploaded/VLDFGFKOWN/XC...
# 3  xc_audio_696093_199  //xeno-canto.org/sounds/uploaded/VLDFGFKOWN/XC...
# 4  xc_audio_695280_200  //xeno-canto.org/sounds/uploaded/XTVEPHMPPJ/XC...
#
#    data-xc-id  page length         contributor        date  ...    country  \
# 0      697285    48   1:50  Franco Vushurovich  2021-10-09  ...  Argentina
# 1      697254    48   0:11  Franco Vushurovich  2021-10-09  ...  Argentina
# 2      697249    48   0:36  Franco Vushurovich  2021-10-09  ...  Argentina
# 3      696093    48   0:48  Franco Vushurovich  2021-10-10  ...  Argentina
# 4      695280    48   4:34        Niels Krabbe  2022-01-03  ...  Argentina
#
#                 location  elev                            type  \
# 0  Mina Clavero, Córdoba  1000                           song
# 1  Mina Clavero, Córdoba  1000    begging call, contact call?
# 2  Mina Clavero, Córdoba  1000  alarm call, call, flight call
# 3  Mina Clavero, Córdoba   900                           song
# 4       Salta: La Misión  1270                           song
#
#                                                 note bird_seen playback_used  \
# 0                                 Quebrada la Gloria        no            no
# 1                                 Quebrada la Gloria        no            no
# 2  Varios individuos sobrevolando dentro de la Qu...       yes            no
# 3       Campo la Gloria al oeste (W) de Mina Clavero        no            no
# 4                                       bird-seen:no        no            no
#
#   class   row     size
# 0     A   4.0  2659330
# 1     A   5.0   270573
# 2     A   6.0   884428
# 3     A   9.0  1169028
# 4     A  10.0  4401294
#
# [5 rows x 21 columns]

# %%
db = src.utils.get_mongo_access()

# %%
for index, row in df.iterrows():
    with open(src.utils.get_mp3_fname(row['key']), "rb") as f:
        encoded = Binary(f.read())
    db.insert_one({
        'key': row['key'],
        'name': row['name'],
        'sci_name': row['sci_name'],
        'type': row['type'],
        'audio': encoded,
    })
